# %%
import pandas as pd
import os

# %% [markdown]
# ## Load Data
# There are two kinds of dataset, one is sone_data, another one is log_data, but both they are in json file format

# %%
cwd = os.getcwd()
song_path = cwd + '/data/song_data/A'
song_path_list = [['A',['A','B','C']],['B',['A','B','C']]]
log_path = cwd + '/data/log_data/2018/11'

# %%
song_df = pd.DataFrame()
for second_path in song_path_list:
    for third_path in second_path[1]:
        tem_path = song_path + '/' + second_path[0] + '/' + third_path
        tem_files = os.listdir(tem_path)
        for tem_file in tem_files :
            if tem_file[-5:] == '.json' :
                tem_df = pd.read_json(tem_path+'/'+tem_file, lines=True)
                song_df = pd.concat([song_df,tem_df],axis=0,ignore_index=True)

# %%
song_df
# Out:
#     num_songs           artist_id  artist_latitude  artist_longitude  \
# 0           1  AR7G5I41187FB4CE6C              NaN               NaN
# 1           1  AR8ZCNI1187B9A069B              NaN               NaN
# 2           1  ARXR32B1187FB57099              NaN               NaN
# 3           1  AR10USD1187B99F3F1              NaN               NaN
# 4           1  ARGSJW91187B9B1D6B         35.21962         -80.01955
# ..        ...                 ...              ...               ...
# 66          1  ARWB3G61187FB49404              NaN               NaN
# 67          1  AR051KA1187B98B2FF              NaN               NaN
# 68          1  AREVWGE1187B9B890A        -13.44200         -41.99520
# 69          1  ARNF6401187FB57032         40.79086         -73.96644
# 70          1  AR558FS1187FB45658              NaN               NaN
#
#                 artist_location            artist_name             song_id  \
# ...

# %%
log_df = pd.DataFrame()
tem_files = os.listdir(log_path)
for tem_file in tem_files :
    if tem_file[-5:] == '.json' :
        tem_df = pd.read_json(log_path+'/'+tem_file, lines=True)
        log_df = pd.concat([log_df,tem_df],axis=0,ignore_index=True)

# %%
log_df
# Out:
#                          artist       auth  firstName gender  itemInSession  \
# 0                      Frumpies  Logged In   Anabelle      F              0
# 1     Kenny G with Peabo Bryson  Logged In   Anabelle      F              1
# 2                   Biffy Clyro  Logged In   Anabelle      F              2
# 3                          None  Logged In       Lily      F              0
# 4                           HIM  Logged In       Lily      F              1
# ...                         ...        ...        ...    ...            ...
# 8051     Motion City Soundtrack  Logged In    Stefany      F              1
# 8052                    Ticanaf  Logged In    Stefany      F              2
# 8053      The Far East Movement  Logged In       Ryan      M              0
# 8054       the bird and the bee  Logged In       Ryan      M              1
# 8055                    Shakira  Logged In  Christian      F              0
#
# ...
